# %%
import pandas as pd

# %%
data = pd.read_csv('cowin_vaccine_data_districtwise.csv',low_memory=False)

# %%
data = data.rename(columns=data.iloc[0])

# %%
data = data.drop(['S No','District_Key','Cowin Key'],axis=1)

# %%
data1 = data[['State_Code','State','Male(Individuals Vaccinated)','Female(Individuals Vaccinated)']].copy()

# %%
data1 = data1.iloc[1:,:]

# %%
cols = []
count = 1
for column in data1.columns:
    if column == 'Male(Individuals Vaccinated)':
        cols.append(f'Male(Individuals Vaccinated){count}')
        count+=1
        continue
    cols.append(column)
data1.columns = cols

# %%
colsa = []
count = 1
for column in data1.columns:
    if column == 'Female(Individuals Vaccinated)':
        colsa.append(f'Female(Individuals Vaccinated){count}')
        count+=1
        continue
    colsa.append(column)
data1.columns = colsa

# %%
df2 = data1.filter(regex='Male')

# %%
df3 = data1.filter(regex='Female')

# %%
newstuff = data1[['State_Code','State']].copy()

# %%
val1 = pd.concat([newstuff, df2], axis=1)
val2 = pd.concat([newstuff, df3], axis=1)

# %%
col_list= list(val1)
col_list.remove('State_Code')
col_list.remove('State')
# col_list

# %%
def sum_frame_by_column(frame, new_col_name, list_of_cols_to_sum):
    frame[new_col_name] = frame[list_of_cols_to_sum].astype(float).sum(axis=1)
    return(frame)

# %%
sum_frame_by_column(val1, 'maledoses', col_list)
# Out:
#     State_Code                        State Male(Individuals Vaccinated)1  \
# 1           AN  Andaman and Nicobar Islands                             0
# 2           AN  Andaman and Nicobar Islands                             0
# 3           AN  Andaman and Nicobar Islands                            12
# 4           AP               Andhra Pradesh                            28
# 5           AP               Andhra Pradesh                            93
# ..         ...                          ...                           ...
# 750         WB                  West Bengal                            29
# 751         WB                  West Bengal                             1
# 752         WB                  West Bengal                             4
# 753         WB                  West Bengal                           NaN
# 754         WB                  West Bengal                            13
#
#     Male(Individuals Vaccinated)2 Male(Individuals Vaccinated)3  \
# 1                               0                             0
# 2                               0                             0
# 3                              12                            29
# 4                              48                            69
# 5                             208                           183
# ..                            ...                           ...
# 750                            58                            98
# 751                             1                            37
# 752                             4                            72
# 753                             0                            41
# 754                            13                            34
#
#     Male(Individuals Vaccinated)4 Male(Individuals Vaccinated)5  \
# 1                               0                             0
# 2                               0                             0
# 3                              53                            67
# 4                             127                           208
# 5                             381                           545
# ..                            ...                           ...
# 750                           101                           101
# 751                            93                            93
# 752                           182                           182
# 753                            91                            91
# 754                            61                            83
#
#     Male(Individuals Vaccinated)6 Male(Individuals Vaccinated)7  \
# 1                               0                             0
# 2                              19                            95
# 3                              91                           136
# 4                             261                           363
# 5                             802                          1036
# ..                            ...                           ...
# 750                           200                           261
# 751                           151                           275
# 752                           182                           395
# 753                           165                           357
# 754                           127                           317
#
#     Male(Individuals Vaccinated)8  ... Male(Individuals Vaccinated)203  \
# 1                              83  ...                           16402
# 2                             115  ...                           52958
# 3                             144  ...                          114800
# 4                             482  ...                          987501
# 5                            1418  ...                         1108178
# ..                            ...  ...                             ...
# 750                           272  ...                          453296
# 751                           278  ...                          259022
# 752                           403  ...                         1003350
# 753                           368  ...                          422381
# 754                           339  ...                          640899
#
#     Male(Individuals Vaccinated)204 Male(Individuals Vaccinated)205  \
# 1                             16408                           16422
# 2                             53331                           53562
# 3                            116644                          118000
# 4                            994293                         1017673
# 5                           1109323                         1150005
# ..                              ...                             ...
# 750                          454166                          462151
# 751                          260740                          262177
# 752                         1018512                         1031355
# 753                          426109                          429350
# 754                          646635                          653967
#
#     Male(Individuals Vaccinated)206 Male(Individuals Vaccinated)207  \
# 1                             16446                           16446
# 2                             53677                           54168
# 3                            119197                          120578
# 4                           1024266                         1059237
# 5                           1159304                         1194614
# ..                              ...                             ...
# 750                          472085                          479133
# 751                          264494                          265671
# 752                         1046886                         1065159
# 753                          440714                          441680
# 754                          666573                          677280
#
#     Male(Individuals Vaccinated)208 Male(Individuals Vaccinated)209  \
# 1                             16446                           16456
# 2                             54182                           54409
# 3                            120743                          121368
# 4                           1065857                         1066936
# 5                           1195827                         1227886
# ..                              ...                             ...
# 750                          483453                          491971
# 751                          266498                          269877
# 752                         1073259                         1082714
# 753                          442151                          452609
# 754                          680799                          687988
#
#     Male(Individuals Vaccinated)210 Male(Individuals Vaccinated)211  \
# 1                             16459                           16468
# 2                             54640                           54856
# 3                            122533                          123444
# 4                           1117223                         1141050
# 5                           1283787                         1288979
# ..                              ...                             ...
# 750                          499442                          508759
# 751                          279691                          284440
# 752                         1122599                         1142488
# 753                          470490                          475245
# 754                          705599                          714378
#
#       maledoses
# 1     1129253.0
# 2     3587351.0
# 3     7783470.0
# 4    62089748.0
# 5    71065673.0
# ..          ...
# 750  32223687.0
# 751  19208890.0
# 752  67778547.0
# 753  28178996.0
# 754  42723778.0
#
# [754 rows x 214 columns]

# %%
col_lista= list(val2)
col_lista.remove('State_Code')
col_lista.remove('State')
# col_lista

# %%
sum_frame_by_column(val2, 'femaledoses', col_lista)
# Out:
#     State_Code                        State Female(Individuals Vaccinated)1  \
# 1           AN  Andaman and Nicobar Islands                               0
# 2           AN  Andaman and Nicobar Islands                               0
# 3           AN  Andaman and Nicobar Islands                              11
# 4           AP               Andhra Pradesh                             259
# 5           AP               Andhra Pradesh                             331
# ..         ...                          ...                             ...
# 750         WB                  West Bengal                               2
# 751         WB                  West Bengal                               0
# 752         WB                  West Bengal                              10
# 753         WB                  West Bengal                             NaN
# 754         WB                  West Bengal                              49
#
#     Female(Individuals Vaccinated)2 Female(Individuals Vaccinated)3  \
# 1                                 0                               0
# 2                                 0                               0
# 3                                11                              13
# 4                               456                             709
# 5                               804                             742
# ..                              ...                             ...
# 750                             115                             222
# 751                               0                              39
# 752                              10                              91
# 753                               0                              60
# 754                              49                             108
#
#     Female(Individuals Vaccinated)4 Female(Individuals Vaccinated)5  \
# 1                                 1                               1
# 2                                 0                               0
# 3                                35                              56
# 4                              1197                            1761
# 5                              1417                            2284
# ..                              ...                             ...
# 750                             239                             239
# 751                              81                              81
# 752                             295                             295
# 753                             196                             196
# 754                             263                             368
#
#     Female(Individuals Vaccinated)6 Female(Individuals Vaccinated)7  \
# 1                                 2                               3
# 2                                14                             149
# 3                               113                             169
# 4                              2235                            2939
# 5                              3057                            3730
# ..                              ...                             ...
# 750                             360                             436
# 751                              99                             345
# 752                             295                             948
# 753                             312                             786
# 754                             578                            1138
#
#     Female(Individuals Vaccinated)8  ... Female(Individuals Vaccinated)203  \
# 1                               123  ...                             14031
# 2                               275  ...                             48333
# 3                               180  ...                            100115
# 4                              3607  ...                           1170116
# 5                              4546  ...                           1316246
# ..                              ...  ...                               ...
# 750                             478  ...                            397471
# 751                             347  ...                            291858
# 752                             969  ...                            926784
# 753                             806  ...                            354774
# 754                            1203  ...                            512682
#
#     Female(Individuals Vaccinated)204 Female(Individuals Vaccinated)205  \
# 1                               14037                             14047
# 2                               48661                             48843
# 3                              101428                            102339
# 4                             1177431                           1202757
# 5                             1317300                           1354796
# ..                                ...                               ...
# 750                            398446                            405217
# 751                            296868                            299907
# 752                            940173                            951733
# 753                            357907                            360557
# 754                            517937                            524701
#
#     Female(Individuals Vaccinated)206 Female(Individuals Vaccinated)207  \
# 1                               14065                             14065
# 2                               48934                             49366
# 3                              103252                            104337
# 4                             1210092                           1246450
# 5                             1363275                           1396355
# ..                                ...                               ...
# 750                            414367                            420819
# 751                            305254                            308248
# 752                            966293                            986115
# 753                            369779                            370603
# 754                            536200                            547315
#
#     Female(Individuals Vaccinated)208 Female(Individuals Vaccinated)209  \
# 1                               14065                             14073
# 2                               49377                             49581
# 3                              104445                            104842
# 4                             1253740                           1254727
# 5                             1397546                           1427510
# ..                                ...                               ...
# 750                            424691                            431850
# 751                            310225                            316208
# 752                            997662                           1009528
# 753                            371041                            379813
# 754                            550378                            556818
#
#     Female(Individuals Vaccinated)210 Female(Individuals Vaccinated)211  \
# 1                               14080                             14090
# 2                               49780                             49972
# 3                              105709                            106397
# 4                             1304917                           1328828
# 5                             1479774                           1484856
# ..                                ...                               ...
# 750                            439453                            448907
# 751                            324013                            327614
# 752                           1044869                           1063614
# 753                            393865                            398040
# 754                            581597                            589599
#
#     femaledoses
# 1      995874.0
# 2     3285690.0
# 3     6524687.0
# 4    70120696.0
# 5    80923503.0
# ..          ...
# 750  25440481.0
# 751  18823325.0
# 752  62424946.0
# 753  23478908.0
# 754  30458540.0
#
# [754 rows x 214 columns]

# %%
finalstuff1 = val1[['State_Code','State','maledoses']].copy()
finalstuff2 = val2[['State_Code','State','femaledoses']].copy()

# %%
result = pd.concat([finalstuff1, finalstuff2], axis=1, join='inner')

# %%
newresult = result[['State_Code','State','maledoses','femaledoses']].copy()

# %%
newresult = newresult.loc[:,~newresult.columns.duplicated()]

# %%
findf = newresult.groupby(['State_Code','State']).sum().reset_index()

# %%
findf['vaccinationratio'] = findf['femaledoses']/findf['maledoses']

# %%
findf = findf.drop(['maledoses','femaledoses'],axis=1)

# %%
findf['State']=findf['State'].str.lower()

# %%
newData = pd.read_excel('DDW_PCA0000_2011_Indiastatedist.xlsx')

# %%
popdata = newData[['Level','Name','TOT_M','TOT_F']].copy()

# %%
rslt_df = popdata[popdata['Level'] == 'STATE'].copy()

# %%
rslt_df.drop_duplicates(subset ="Name",keep = 'first', inplace = True)

# %%
rslt_df['populationratio'] = rslt_df['TOT_F']/rslt_df['TOT_M']

# %%
rslt_df.sort_values("Name", axis = 0, ascending = True,inplace = True)

# %%
rslt_df.reset_index(inplace = True)

# %%
rslt_df = rslt_df.drop(['index'],axis=1)

# %%
newrslt_df = rslt_df[['Name','populationratio']].copy()

# %%
newrslt_df['Name'] = newrslt_df['Name'].str.lower()

# %%
newrslt_df.rename(columns = {'Name':'State'}, inplace = True)

# %%
int_df = pd.merge(findf, newrslt_df, how='inner', on=['State'])

# %%
int_df['ratioofratio'] = int_df['vaccinationratio']/int_df['populationratio']

# %%
int_df.rename(columns = {'State_Code':'stateid'}, inplace = True)

# %%
int_df = int_df.drop(['State'],axis=1)

# %%
int_df.sort_values("ratioofratio", axis = 0, ascending = True,inplace = True)

# %%
int_df.reset_index(inplace = True)

# %%
sachinint_df = int_df[['stateid','vaccinationratio','populationratio','ratioofratio']].copy()

# %%
sachinint_df.to_csv('vaccination-population-ratio-states.csv')

# %%
rawdata = pd.read_csv('cowin_vaccine_data_districtwise.csv',low_memory=False)

# %%
rawdata = rawdata.rename(columns=data.iloc[0])

# %%
rawdata = rawdata.drop(['S No','State_Code','State','Cowin Key'],axis=1)

# %%
rawdata = rawdata.rename(columns=rawdata.iloc[0])

# %%
thing = rawdata[['District_Key','District','Male(Individuals Vaccinated)','Female(Individuals Vaccinated)']].copy()

# %%
thing = thing.iloc[1:,:]

# %%
acols = []
count = 1
for column in thing.columns:
    if column == 'Male(Individuals Vaccinated)':
        acols.append(f'Male(Individuals Vaccinated){count}')
        count+=1
        continue
    acols.append(column)
thing.columns = acols
bcols = []
count = 1
for column in thing.columns:
    if column == 'Female(Individuals Vaccinated)':
        bcols.append(f'Female(Individuals Vaccinated){count}')
        count+=1
        continue
    bcols.append(column)
thing.columns = bcols

# %%
bat1 = thing.filter(regex='Male')
bat2 = thing.filter(regex='Female')

# %%
stumps = thing[['District_Key','District']].copy()

# %%
sachin1 = pd.concat([stumps, bat1], axis=1)
sachin2 = pd.concat([stumps, bat2], axis=1)

# %%
column_list1= list(sachin1)
column_list1.remove('District_Key')
column_list1.remove('District')
# col_list

# %%
def sum_frame_by_column(frame, new_col_name, list_of_cols_to_sum):
    frame[new_col_name] = frame[list_of_cols_to_sum].astype(float).sum(axis=1)
    return(frame)

# %%
sum_frame_by_column(sachin1, 'maledoses', column_list1)
# Out:
#                     District_Key                  District  \
# 1                    AN_Nicobars                  Nicobars
# 2    AN_North and Middle Andaman  North and Middle Andaman
# 3               AN_South Andaman             South Andaman
# 4                   AP_Anantapur                 Anantapur
# 5                    AP_Chittoor                  Chittoor
# ..                           ...                       ...
# 750                   WB_Purulia                   Purulia
# 751                   WB_Birbhum                   Birbhum
# 752         WB_South 24 Parganas         South 24 Parganas
# 753            WB_Uttar Dinajpur            Uttar Dinajpur
# 754         WB_Paschim Bardhaman         Paschim Bardhaman
#
#     Male(Individuals Vaccinated)1 Male(Individuals Vaccinated)2  \
# 1                               0                             0
# 2                               0                             0
# 3                              12                            12
# 4                              28                            48
# 5                              93                           208
# ..                            ...                           ...
# 750                            29                            58
# 751                             1                             1
# 752                             4                             4
# 753                           NaN                             0
# 754                            13                            13
#
#     Male(Individuals Vaccinated)3 Male(Individuals Vaccinated)4  \
# 1                               0                             0
# 2                               0                             0
# 3                              29                            53
# 4                              69                           127
# 5                             183                           381
# ..                            ...                           ...
# 750                            98                           101
# 751                            37                            93
# 752                            72                           182
# 753                            41                            91
# 754                            34                            61
#
#     Male(Individuals Vaccinated)5 Male(Individuals Vaccinated)6  \
# 1                               0                             0
# 2                               0                            19
# 3                              67                            91
# 4                             208                           261
# 5                             545                           802
# ..                            ...                           ...
# 750                           101                           200
# 751                            93                           151
# 752                           182                           182
# 753                            91                           165
# 754                            83                           127
#
#     Male(Individuals Vaccinated)7 Male(Individuals Vaccinated)8  ...  \
# 1                               0                            83  ...
# 2                              95                           115  ...
# 3                             136                           144  ...
# 4                             363                           482  ...
# 5                            1036                          1418  ...
# ..                            ...                           ...  ...
# 750                           261                           272  ...
# 751                           275                           278  ...
# 752                           395                           403  ...
# 753                           357                           368  ...
# 754                           317                           339  ...
#
#     Male(Individuals Vaccinated)203 Male(Individuals Vaccinated)204  \
# 1                             16402                           16408
# 2                             52958                           53331
# 3                            114800                          116644
# 4                            987501                          994293
# 5                           1108178                         1109323
# ..                              ...                             ...
# 750                          453296                          454166
# 751                          259022                          260740
# 752                         1003350                         1018512
# 753                          422381                          426109
# 754                          640899                          646635
#
#     Male(Individuals Vaccinated)205 Male(Individuals Vaccinated)206  \
# 1                             16422                           16446
# 2                             53562                           53677
# 3                            118000                          119197
# 4                           1017673                         1024266
# 5                           1150005                         1159304
# ..                              ...                             ...
# 750                          462151                          472085
# 751                          262177                          264494
# 752                         1031355                         1046886
# 753                          429350                          440714
# 754                          653967                          666573
#
#     Male(Individuals Vaccinated)207 Male(Individuals Vaccinated)208  \
# 1                             16446                           16446
# 2                             54168                           54182
# 3                            120578                          120743
# 4                           1059237                         1065857
# 5                           1194614                         1195827
# ..                              ...                             ...
# 750                          479133                          483453
# 751                          265671                          266498
# 752                         1065159                         1073259
# 753                          441680                          442151
# 754                          677280                          680799
#
#     Male(Individuals Vaccinated)209 Male(Individuals Vaccinated)210  \
# 1                             16456                           16459
# 2                             54409                           54640
# 3                            121368                          122533
# 4                           1066936                         1117223
# 5                           1227886                         1283787
# ..                              ...                             ...
# 750                          491971                          499442
# 751                          269877                          279691
# 752                         1082714                         1122599
# 753                          452609                          470490
# 754                          687988                          705599
#
#     Male(Individuals Vaccinated)211   maledoses
# 1                             16468   1129253.0
# 2                             54856   3587351.0
# 3                            123444   7783470.0
# 4                           1141050  62089748.0
# 5                           1288979  71065673.0
# ..                              ...         ...
# 750                          508759  32223687.0
# 751                          284440  19208890.0
# 752                         1142488  67778547.0
# 753                          475245  28178996.0
# 754                          714378  42723778.0
#
# [754 rows x 214 columns]

# %%
column_list2= list(sachin2)
column_list2.remove('District_Key')
column_list2.remove('District')

# %%
sum_frame_by_column(sachin2, 'femaledoses', column_list2)
# Out:
#                     District_Key                  District  \
# 1                    AN_Nicobars                  Nicobars
# 2    AN_North and Middle Andaman  North and Middle Andaman
# 3               AN_South Andaman             South Andaman
# 4                   AP_Anantapur                 Anantapur
# 5                    AP_Chittoor                  Chittoor
# ..                           ...                       ...
# 750                   WB_Purulia                   Purulia
# 751                   WB_Birbhum                   Birbhum
# 752         WB_South 24 Parganas         South 24 Parganas
# 753            WB_Uttar Dinajpur            Uttar Dinajpur
# 754         WB_Paschim Bardhaman         Paschim Bardhaman
#
#     Female(Individuals Vaccinated)1 Female(Individuals Vaccinated)2  \
# 1                                 0                               0
# 2                                 0                               0
# 3                                11                              11
# 4                               259                             456
# 5                               331                             804
# ..                              ...                             ...
# 750                               2                             115
# 751                               0                               0
# 752                              10                              10
# 753                             NaN                               0
# 754                              49                              49
#
#     Female(Individuals Vaccinated)3 Female(Individuals Vaccinated)4  \
# 1                                 0                               1
# 2                                 0                               0
# 3                                13                              35
# 4                               709                            1197
# 5                               742                            1417
# ..                              ...                             ...
# 750                             222                             239
# 751                              39                              81
# 752                              91                             295
# 753                              60                             196
# 754                             108                             263
#
#     Female(Individuals Vaccinated)5 Female(Individuals Vaccinated)6  \
# 1                                 1                               2
# 2                                 0                              14
# 3                                56                             113
# 4                              1761                            2235
# 5                              2284                            3057
# ..                              ...                             ...
# 750                             239                             360
# 751                              81                              99
# 752                             295                             295
# 753                             196                             312
# 754                             368                             578
#
#     Female(Individuals Vaccinated)7 Female(Individuals Vaccinated)8  ...  \
# 1                                 3                             123  ...
# 2                               149                             275  ...
# 3                               169                             180  ...
# 4                              2939                            3607  ...
# 5                              3730                            4546  ...
# ..                              ...                             ...  ...
# 750                             436                             478  ...
# 751                             345                             347  ...
# 752                             948                             969  ...
# 753                             786                             806  ...
# 754                            1138                            1203  ...
#
#     Female(Individuals Vaccinated)203 Female(Individuals Vaccinated)204  \
# 1                               14031                             14037
# 2                               48333                             48661
# 3                              100115                            101428
# 4                             1170116                           1177431
# 5                             1316246                           1317300
# ..                                ...                               ...
# 750                            397471                            398446
# 751                            291858                            296868
# 752                            926784                            940173
# 753                            354774                            357907
# 754                            512682                            517937
#
#     Female(Individuals Vaccinated)205 Female(Individuals Vaccinated)206  \
# 1                               14047                             14065
# 2                               48843                             48934
# 3                              102339                            103252
# 4                             1202757                           1210092
# 5                             1354796                           1363275
# ..                                ...                               ...
# 750                            405217                            414367
# 751                            299907                            305254
# 752                            951733                            966293
# 753                            360557                            369779
# 754                            524701                            536200
#
#     Female(Individuals Vaccinated)207 Female(Individuals Vaccinated)208  \
# 1                               14065                             14065
# 2                               49366                             49377
# 3                              104337                            104445
# 4                             1246450                           1253740
# 5                             1396355                           1397546
# ..                                ...                               ...
# 750                            420819                            424691
# 751                            308248                            310225
# 752                            986115                            997662
# 753                            370603                            371041
# 754                            547315                            550378
#
#     Female(Individuals Vaccinated)209 Female(Individuals Vaccinated)210  \
# 1                               14073                             14080
# 2                               49581                             49780
# 3                              104842                            105709
# 4                             1254727                           1304917
# 5                             1427510                           1479774
# ..                                ...                               ...
# 750                            431850                            439453
# 751                            316208                            324013
# 752                           1009528                           1044869
# 753                            379813                            393865
# 754                            556818                            581597
#
#     Female(Individuals Vaccinated)211 femaledoses
# 1                               14090    995874.0
# 2                               49972   3285690.0
# 3                              106397   6524687.0
# 4                             1328828  70120696.0
# 5                             1484856  80923503.0
# ..                                ...         ...
# 750                            448907  25440481.0
# 751                            327614  18823325.0
# 752                           1063614  62424946.0
# 753                            398040  23478908.0
# 754                            589599  30458540.0
#
# [754 rows x 214 columns]

# %%
lion1 = sachin1[['District_Key','District','maledoses']].copy()
lion2 = sachin2[['District_Key','District','femaledoses']].copy()

# %%
mergedf = pd.concat([lion1, lion2], axis=1, join='inner')

# %%
a = mergedf.loc[:,~mergedf.columns.duplicated()]

# %%
a_list = a['femaledoses']/a['maledoses']

# %%
a_list_a = pd.DataFrame(a_list)

# %%
a_list_a.rename(columns={0:'vaccinationratio'},inplace=True)

# %%
newmergedf = pd.concat([a,a_list_a],axis=1)

# %%
thenewmergedf = newmergedf[['District_Key','District','vaccinationratio']].copy()
finalnewmergedf = thenewmergedf[['District','vaccinationratio']].copy()
finalnewmergedf['District'] = finalnewmergedf['District'].str.lower()

# %%
kohli = pd.read_excel('DDW_PCA0000_2011_Indiastatedist.xlsx')

# %%
pdata = kohli[['Level','Name','TOT_M','TOT_F']].copy()

# %%
wave = pdata[pdata['Level'] == 'DISTRICT'].copy()
wave.drop_duplicates(subset ="Name",keep = 'first', inplace = True)

# %%
wave['populationratio'] = wave['TOT_F']/wave['TOT_M']

# %%
wave.rename(columns = {'Name':'District'}, inplace = True)

# %%
thenewwave = wave[['District','populationratio']].copy()
thenewwave['District'] = thenewwave['District'].str.lower()

# %%
finalint_df = pd.merge(finalnewmergedf, thenewwave, how='inner', on=['District'])
finalint_df['ratioofratio'] = finalint_df['vaccinationratio']/finalint_df['populationratio']

# %%
distkeydist = sachin1[['District','District_Key']].copy()

# %%
distkeydist['District'] = distkeydist['District'].str.lower()

# %%
python = pd.merge(finalint_df, distkeydist, how='inner', on=['District'])

# %%
python = python[['District_Key','vaccinationratio','populationratio','ratioofratio']]

# %%
python.drop_duplicates(subset ="District_Key",keep = 'first', inplace = True)

# %%
python.rename(columns = {'District_Key':'districtid'}, inplace = True)

# %%
python.sort_values("ratioofratio", axis = 0, ascending = True,inplace = True)

# %%
python.reset_index(inplace = True)

# %%
new_python = python[['districtid','vaccinationratio','populationratio','ratioofratio']].copy()

# %%
new_python.drop_duplicates(subset ="districtid",keep = 'first', inplace = True)

# %%
new_python.to_csv('vaccination-population-ratio-districts.csv')

# %%
fin_sum_state = newresult.sum(axis = 0, skipna = True)

# %%
fin_sum_state = fin_sum_state.to_frame()

# %%
fin_sum_state = fin_sum_state.transpose()

# %%
fin_sum_state = fin_sum_state[['maledoses','femaledoses']]

# %%
fin_sum_state['vaccinationratio'] = fin_sum_state['femaledoses']/fin_sum_state['maledoses']

# %%
fin_sum_state['overall'] = 'overall'

# %%
fin_rslt_df=rslt_df[['TOT_M','TOT_F']].copy()

# %%
fin_rslt_df= fin_rslt_df.sum(axis = 0, skipna = True)

# %%
fin_rslt_df = fin_rslt_df.to_frame()

# %%
fin_rslt_df = fin_rslt_df.transpose()

# %%
fin_rslt_df['populationratio'] = fin_rslt_df['TOT_F']/fin_rslt_df['TOT_M']

# %%
fin_rslt_df['overall'] = 'overall'

# %%
final_count=pd.merge(fin_rslt_df, fin_sum_state, how='inner', on=['overall'])

# %%
final_count = final_count[['vaccinationratio','populationratio']]

# %%
final_count['ratioofratio'] = final_count['vaccinationratio']/final_count['populationratio']

# %%
final_count['overall'] = 'overall'

# %%
final_count = final_count[['overall','vaccinationratio','populationratio','ratioofratio']]

# %%
final_count.to_csv('vaccination-population-ratio-overall.csv')
